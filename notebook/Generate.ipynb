# %%
import random

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import psycopg2 #install psycopg2-binary if linux
import sqlalchemy

import faker
from tqdm import tqdm

# %% [markdown]
# ### Générer les données des produits

# %%
nom_produit = ['Bridel lait instant', 'lait tino en boite', 'Bridel lait uth', 'Ndolo', 
               'Tampico citrus', 'Tampico island', 'Cafe pele', 'Cafe coa energy',
               'Cremica butter', 'Cuetara', 'Lays Saled', 'Pringles BBQ', 'cornichons 700g',
               'cornichons 300 g', 'Extra abricot', 'Extra fraise']

cat_produits = {
    "produits frais":{
        "produits laitiers" : ["lait en poudre", "lait liquide"],
        "boissons": ["jus", "boissons chaudes"]
    },
    "produit secs":{
        "biscuits": ["cookies", "croustillants"],
        "produits conserve": ["Cornichons", "confiture"]
    }
}

data = []
produitID = 100

for category, sub_level1 in cat_produits.items():
    for sub_cat1, sub_level2 in sub_level1.items():
        for sub_cat2 in sub_level2:
            for i in range(2):
                produit = nom_produit.pop(0)
                data.append(
                    {
                        "ProduitID" : f"pr{produitID}",
                        "categorie" : category,
                        "sousCategorie1" : sub_cat1,
                        "sousCategorie2" : sub_cat2, 
                        "NomProduit" : produit
                    }
                )

                produitID+=1

df_produit = pd.DataFrame(data)
df_produit
# Out:
#    ProduitID       categorie     sousCategorie1    sousCategorie2  \
# 0      pr100  produits frais  produits laitiers    lait en poudre
# 1      pr101  produits frais  produits laitiers    lait en poudre
# 2      pr102  produits frais  produits laitiers      lait liquide
# 3      pr103  produits frais  produits laitiers      lait liquide
# 4      pr104  produits frais           boissons               jus
# 5      pr105  produits frais           boissons               jus
# 6      pr106  produits frais           boissons  boissons chaudes
# 7      pr107  produits frais           boissons  boissons chaudes
# 8      pr108    produit secs           biscuits           cookies
# 9      pr109    produit secs           biscuits           cookies
# 10     pr110    produit secs           biscuits     croustillants
# 11     pr111    produit secs           biscuits     croustillants
# 12     pr112    produit secs  produits conserve        Cornichons
# 13     pr113    produit secs  produits conserve        Cornichons
# 14     pr114    produit secs  produits conserve         confiture
# 15     pr115    produit secs  produits conserve         confiture
#
#              NomProduit
# 0   Bridel lait instant
# 1    lait tino en boite
# 2       Bridel lait uth
# 3                 Ndolo
# 4        Tampico citrus
# 5        Tampico island
# 6             Cafe pele
# 7       Cafe coa energy
# 8        Cremica butter
# 9               Cuetara
# 10           Lays Saled
# 11         Pringles BBQ
# 12      cornichons 700g
# 13     cornichons 300 g
# 14        Extra abricot
# 15         Extra fraise

# %%
df_produit.to_parquet("../Data/produit.parquet")

# %% [markdown]
# ### Localisation

# %%
location_data = []

location = {
    "littoral": {
        "Douala" : ["Bonapriso", "Akwa", "Bonanjo", "Deïdo", "Bali", "Bépanda", "Makepe", "Ndogbong", "Bonamoussadi", "New-Bell"],
    },
    "Ouest":{
        "Bafoussam": "bafoussam",
        "Bafang": "bafang",
        "Foumban": "foumban",
        "Dschang": "dschang",
        "Bamenda": "bamenda",
        "Bansoa": "bansoa",
        "MB'DA": "mb'da",
    },
    "Centre":{
        "Yaoundé": ["Bastos", "Etoudi", "Ngousso", "Mvog-Mbi", "Emana", "Essos", "Melen", "Nlongkak", "Ngoa-Ekelle","Mokolo"],
        "Makenene": "makenene",
    },
} 

locationID = 100

for region, elm1 in location.items():
    for ville, elm2 in elm1.items():
        for quartier in elm2:
            location_data.append({
                "locationID": f"lc{locationID}",
                "region": region,
                "ville": ville,
                "quartier": quartier
            })
            locationID+=1

df_location = pd.DataFrame(location_data)
df_location.head()

df_location.to_parquet("../Data/location.parquet")

# %%
fake = faker.Faker()

# %% [markdown]
# ### Génération clients

# %%
client_data = []
location_id = list(df_location.locationID)

cat_client = ["DEPOT", "Prestige", "porte à porte", "Ecole", "Grossiste", "Divers"]
id=100

for i in tqdm(range(500)):
    clientID = f"cl{id}"
    client_name = fake.company()
    category = random.choices(cat_client, weights=[0.25, 0.35, 0.025, 0.1, 0.175, 0.1])[0]
    client_location = random.choice(location_id)

    id+=1
    client_data.append({
        "clientID": clientID,
        "clientName": client_name,
        "category": category,
        "location": client_location
    })

df_client = pd.DataFrame(client_data)
df_client.head()
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# 100%|██████████| 500/500 [00:00<00:00, 2326.45it/s]
#   clientID                     clientName   category location
# 0    cl100  Browning, Bowen and Carpenter   Prestige    lc126
# 1    cl101   Fletcher, Bryan and Phillips   Prestige    lc172
# 2    cl102              Rodriguez-Summers     Divers    lc109
# 3    cl103                   Owens-Bishop  Grossiste    lc162
# 4    cl104                  Taylor-Jordan   Prestige    lc140
